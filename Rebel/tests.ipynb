# %%
# %load_ext autoreload
# %autoreload 2

# %%
import networkx as nx
import numpy as np
import game_tree as gt
import games.rock_paper_scissors as RPS

# %%
game = RPS.RPS()

# %%
init_state = np.array([0,0])
init_belief = np.ones((2,3))/3.
init_PBS = gt.PBS(init_state,init_belief)
init_PBS

# %%
tree = gt.recursive_game_tree(init_PBS, game)

# %%
tree.build_depth_limited_subgame(4)

# %%
pos = nx.layout.planar_layout(tree.tree)
# Out:
# C:\Users\dwmar\Anaconda3\envs\tf-pip\lib\site-packages\networkx\drawing\layout.py:950: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   pos = np.row_stack((pos[x] for x in node_list))

# %%
nx.draw(tree.tree,pos, with_labels=False, arrows=True)
labels = nx.get_edge_attributes(tree.tree,'action')
g = nx.draw_networkx_edge_labels(tree.tree, pos, labels)

# %%
nx.draw_planar(tree.tree)
# Out:
# C:\Users\dwmar\Anaconda3\envs\tf-pip\lib\site-packages\networkx\drawing\layout.py:950: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   pos = np.row_stack((pos[x] for x in node_list))

# %%
tree.tree.nodes('terminal')
# Out:
# NodeDataView({('root',): False, ('root', 0): False, ('root', 1): False, ('root', 2): False, ('root', 0, 0): True, ('root', 0, 1): True, ('root', 0, 2): True, ('root', 1, 0): True, ('root', 1, 1): True, ('root', 1, 2): True, ('root', 2, 0): True, ('root', 2, 1): True, ('root', 2, 2): True}, data='terminal')

# %%
tree.set_leaf_values('hi')
tree.tree.nodes('value')
# Out:
# ('root',)
# ('root', 0)
# ('root', 0, 0)
# setting terminal
# ('root', 0, 1)
# setting terminal
# ('root', 0, 2)
# setting terminal
# ('root', 1)
# ('root', 1, 0)
# setting terminal
# ('root', 1, 1)
# setting terminal
# ('root', 1, 2)
# setting terminal
# ('root', 2)
# ('root', 2, 0)
# setting terminal
# ('root', 2, 1)
# setting terminal
# ('root', 2, 2)
# setting terminal
# NodeDataView({('root',): None, ('root', 0): None, ('root', 1): None, ('root', 2): None, ('root', 0, 0): 0.7777777777777777, ('root', 0, 1): 0.7777777777777777, ('root', 0, 2): 0.7777777777777777, ('root', 1, 0): 0.7777777777777777, ('root', 1, 1): 0.7777777777777777, ('root', 1, 2): 0.7777777777777777, ('root', 2, 0): 0.7777777777777777, ('root', 2, 1): 0.7777777777777777, ('root', 2, 2): 0.7777777777777777}, data='value')

# %%
tree.compute_ev()
# Out:
# 0.7777777777777776

# %%
len(tree.tree.nodes())
# Out:
# 13

# %%
tree.tree.nodes('value')
# Out:
# NodeDataView({('root',): 0.7777777777777776, ('root', 0): 0.7777777777777776, ('root', 1): 0.7777777777777776, ('root', 2): 0.7777777777777776, ('root', 0, 0): 0.7777777777777777, ('root', 0, 1): 0.7777777777777777, ('root', 0, 2): 0.7777777777777777, ('root', 1, 0): 0.7777777777777777, ('root', 1, 1): 0.7777777777777777, ('root', 1, 2): 0.7777777777777777, ('root', 2, 0): 0.7777777777777777, ('root', 2, 1): 0.7777777777777777, ('root', 2, 2): 0.7777777777777777}, data='value')
